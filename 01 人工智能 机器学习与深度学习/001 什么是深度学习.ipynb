# %% [markdown]
# # 1.1 人工智能、机器学习&深度学习
#
# ## 三者的关系
#
# ![001.png](images/001-001.png)
#
#
# ## 1.1.1 人工智能
#
# - 符号主义人工智能 （Symbolic AI）
#     给出所有规则，能解决所有问题
#
# ## 1.1.2 机器智能
#
# `图灵`: 通用计算机能够学习与创新
#
# ![002](images/001-002.png)
#
# 机器学习系统是训练出来，而不是明确程序编写出来的
#
# ## 1.1.3 从数据中学习表示
#
# 机器学习`三要素`:
# - 输入数据点 input data points
# - 预期输出的示例 examples of the expected output
# - 衡量算法好坏的方法 A way to measure whether the algorithm is doing a good job
#
# ## 1.1.4 深度学习的`深度`
#
# 深度学习是机器学习的一个分支。从连续的层（layer）中进行学习，更有意义的表示方式
#
# ## 1.1.5 深度学习的工作原理
#
# ![003](images/001-003.png)
# ![%E5%9B%BE%E7%89%87-4.png](images/001-004.png)
# ![%E5%9B%BE%E7%89%87-5.png](images/001-005.png)
